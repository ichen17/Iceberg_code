# %%
# !apt install texlive-fonts-recommended texlive-fonts-extra cm-super dvipng
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cm-super-minimal dvisvgm fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-cabin fonts-cantarell fonts-comfortaa fonts-croscore
#   fonts-crosextra-caladea fonts-crosextra-carlito fonts-dejavu-core fonts-dejavu-extra
#   fonts-droid-fallback fonts-ebgaramond fonts-ebgaramond-extra fonts-font-awesome
#   fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia fonts-gfs-complutum fonts-gfs-didot
#   fonts-gfs-neohellenic fonts-gfs-olga fonts-gfs-solomos fonts-go fonts-junicode fonts-lato
#   fonts-linuxlibertine fonts-lmodern fonts-lobster fonts-lobstertwo fonts-noto-color-emoji
#   fonts-noto-core fonts-noto-mono fonts-oflb-asana-math fonts-open-sans fonts-roboto-unhinted
#   fonts-sil-charis fonts-sil-gentium fonts-sil-gentium-basic fonts-sil-gentiumplus
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
import scipy

# %%
params = {"text.usetex" : True,
          "lines.markersize": 1,
          "axes.labelpad": 1,
          "axes.labelpad": 1}#
plt.rcParams.update(params)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path='/content/gdrive/MyDrive/Iceberg/L_30/'

# %%
path50='/content/gdrive/MyDrive/Iceberg/L_50/'

# %%
with open(path+'Unenc_u_30_m1.pickle', 'rb') as handle:
    uval_data_u = pickle.load(handle)['1.0']

with open(path+'enc_val_1_u_30_ft.pickle', 'rb') as handle:
    val_data_1 = pickle.load(handle)['0.1']

with open(path+'EXT_expvals_s_30_1.npy', 'rb') as f:
    ext_val=np.load(f)

# %%
ext_val
# Out:
# array([ 0.48911703+0.00000000e+00j,  0.20681802+0.00000000e+00j,
#         0.05769926+0.00000000e+00j,  0.05068355-1.73472348e-18j,
#         0.50892231+0.00000000e+00j,  0.03037431+0.00000000e+00j,
#        -0.01917516-8.67361738e-19j,  0.00724491+0.00000000e+00j,
#        -0.00123756-2.16840434e-19j,  0.99470818+0.00000000e+00j,
#         0.02384612+0.00000000e+00j])

# %%
val_data_1
# Out:
# [0.4911738216751726,
#  0.20457741554657943,
#  0.055661301687608425,
#  0.05007594786535387,
#  0.5064955846026142,
#  0.03187973747421432,
#  -0.01690627792703267,
#  0.00970640862880734,
#  -0.0011644217372234757,
#  0.9926714255679144,
#  0.026918643683063292]

# %%
errors_30 = []
for data in [uval_data_u,val_data_1]:
    errors_30.append(abs(ext_val - data))

# %%
with open(path+'Unenc_u_30_m.pickle', 'rb') as handle:
    uval_data_10 = pickle.load(handle)['1.0']

with open(path+'enc_val_1_u_30_ft.pickle', 'rb') as handle:
    val_data_1_1 = pickle.load(handle)['1.0']

with open(path+'enc_val_1_3_u_30_m.pickle', 'rb') as handle:
    val_data_1_3 = pickle.load(handle)['1.0']

with open(path+'enc_val_2_u_30_ft.pickle', 'rb') as handle:
    val_data_2_1 = pickle.load(handle)['1.0']

with open(path+'enc_val_2_3_u_30_m.pickle', 'rb') as handle:
    val_data_2_3 = pickle.load(handle)['1.0']

with open(path+'enc_val_3_u_30_ft.pickle', 'rb') as handle:
    val_data_3_1 = pickle.load(handle)['1.0']

with open(path+'enc_val_3_3_u_30_m.pickle', 'rb') as handle:
    val_data_3_3 = pickle.load(handle)['1.0']

with open(path+'enc_val_4_u_30_ft.pickle', 'rb') as handle:
    val_data_4_1 = pickle.load(handle)['1.0']

with open(path+'enc_val_4_3_u_30_1.pickle', 'rb') as handle:
    val_data_4_3 = pickle.load(handle)['1.0']

with open(path+'EXT_expvals_s_30_1.npy', 'rb') as f:
    ext_val=np.load(f)

# %%
errors_30 = []
#for data in [uval_data_10,val_data_1_1,val_data_2_1,val_data_3_1,val_data_4_1]:
for data in [uval_data_10,val_data_1_1,val_data_2_1,val_data_3_1,val_data_4_1]:
    errors_30.append(abs(ext_val - data))

# %%
fig, ax = plt.subplots(figsize=(7, 4))
positions = np.arange(len(errors_30)) + 1

ax.boxplot(errors_30, positions=positions, widths=0.6, patch_artist=True,
        boxprops=dict(facecolor=f'C{0}', color=f'C{0}'),
        medianprops=dict(color='black'))

xlabels = [
        "Unencode",
        "N=1",
        "N=2",
        "N=3",
        "N=4"
        ]
ax.set_xticklabels(xlabels, rotation=0, fontsize=12)
ax.set_ylabel('Error of density matrix', fontsize=12)

plt.yscale('log')
plt.tight_layout()

# %%
with open(path50+'Unenc_u_50_m.pickle', 'rb') as handle:
    uval_data_10 = pickle.load(handle)['1.0']

# %%
with open(path50+'enc_val_1_u_50_ft.pickle', 'rb') as handle:
    val_data_1_1 = pickle.load(handle)['1.0']

with open(path50+'enc_val_1_3_u_50_m.pickle', 'rb') as handle:
    val_data_1_3 = pickle.load(handle)['1.0']

with open(path50+'enc_val_2_u_50_ft.pickle', 'rb') as handle:
    val_data_2_1 = pickle.load(handle)['1.0']

with open(path50+'enc_val_2_3_u_50_m.pickle', 'rb') as handle:
    val_data_2_3 = pickle.load(handle)['1.0']

with open(path50+'enc_val_3_u_50_ft.pickle', 'rb') as handle:
    val_data_3_1 = pickle.load(handle)['1.0']

with open(path50+'enc_val_3_3_u_50_m.pickle', 'rb') as handle:
    val_data_3_3 = pickle.load(handle)['1.0']

with open(path50+'enc_val_4_u_50_ft.pickle', 'rb') as handle:
    val_data_4_1 = pickle.load(handle)['1.0']

with open(path50+'enc_val_4_3_u_50_m.pickle', 'rb') as handle:
    val_data_4_3 = pickle.load(handle)['1.0']

# %%
with open(path50+'EXT_expvals_u_50_1.npy', 'rb') as f:
    ext_val=np.load(f)

# %%
errors_50 = []
for data in [uval_data_10,val_data_1_1,val_data_2_1,val_data_3_1,val_data_4_1]:
    errors_50.append(abs(ext_val - data))

# %%
fig, ax = plt.subplots(figsize=(7, 4))
positions = np.arange(len(errors_50)) + 1

ax.boxplot(errors_50, positions=positions, widths=0.6, patch_artist=True,
        boxprops=dict(facecolor=f'C{0}', color=f'C{0}'),
        medianprops=dict(color='black'))

xlabels = [
        "Unencode",
        "N=1",
        "N=2",
        "N=3",
        "N=4"
        ]
ax.set_xticklabels(xlabels, rotation=0, fontsize=12)
ax.set_ylabel('Error of density matrix', fontsize=12)

plt.yscale('log')
plt.tight_layout()

# %%
Pd_ex=np.zeros((4,4),dtype=np.complex128)
Pd_ex[0,0]=ext_val[0]
Pd_ex[1,1]=ext_val[4]
Pd_ex[2,2]=ext_val[7]
Pd_ex[3,3]=ext_val[9]

Pd_ex[0,1]=ext_val[1]
Pd_ex[1,0]=ext_val[1]

Pd_ex[0,2]=ext_val[2]
Pd_ex[2,0]=ext_val[2]

Pd_ex[0,3]=ext_val[3]
Pd_ex[3,0]=ext_val[3]

Pd_ex[1,2]=ext_val[5]
Pd_ex[2,1]=ext_val[5]

Pd_ex[1,3]=ext_val[6]
Pd_ex[3,1]=ext_val[6]

Pd_ex[2,3]=ext_val[8]
Pd_ex[3,2]=ext_val[8]

# %%
with open(path50+'Unenc_u_50_m.pickle', 'rb') as handle:
    uval_data_10_all = pickle.load(handle)
with open(path50+'enc_val_1_u_50_ft.pickle', 'rb') as handle:
    val_data_1_1_all = pickle.load(handle)
with open(path50+'enc_val_2_u_50_ft.pickle', 'rb') as handle:
    val_data_2_1_all = pickle.load(handle)
with open(path50+'enc_val_3_u_50_ft.pickle', 'rb') as handle:
    val_data_3_1_all = pickle.load(handle)
with open(path50+'enc_val_4_u_50_ft.pickle', 'rb') as handle:
    val_data_4_1_all = pickle.load(handle)

un_dis=[]
en_dis_4=[]
en_dis_3=[]
en_dis_2=[]
en_dis_1=[]
for string in ['0.1','0.2','0.5','1.0','2.0']:
    uval_data_10=uval_data_10_all[string]
    val_data_1_1=val_data_1_1_all[string]
    val_data_2_1=val_data_2_1_all[string]
    val_data_3_1=val_data_3_1_all[string]
    val_data_4_1=val_data_4_1_all[string]

    Pd_un=np.zeros((4,4),dtype=np.complex128)
    Pd_un[0,0]=uval_data_10[0]
    Pd_un[1,1]=uval_data_10[4]
    Pd_un[2,2]=uval_data_10[7]
    Pd_un[3,3]=uval_data_10[9]

    Pd_un[0,1]=uval_data_10[1]
    Pd_un[1,0]=uval_data_10[1]

    Pd_un[0,2]=uval_data_10[2]
    Pd_un[2,0]=uval_data_10[2]

    Pd_un[0,3]=uval_data_10[3]
    Pd_un[3,0]=uval_data_10[3]

    Pd_un[1,2]=uval_data_10[5]
    Pd_un[2,1]=uval_data_10[5]

    Pd_un[1,3]=uval_data_10[6]
    Pd_un[3,1]=uval_data_10[6]

    Pd_un[2,3]=uval_data_10[8]
    Pd_un[3,2]=uval_data_10[8]

    un_dis.append(0.5*scipy.linalg.norm(Pd_un-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_1_1[0]
    Pd_en[1,1]=val_data_1_1[4]
    Pd_en[2,2]=val_data_1_1[7]
    Pd_en[3,3]=val_data_1_1[9]

    Pd_en[0,1]=val_data_1_1[1]
    Pd_en[1,0]=val_data_1_1[1]

    Pd_en[0,2]=val_data_1_1[2]
    Pd_en[2,0]=val_data_1_1[2]

    Pd_en[0,3]=val_data_1_1[3]
    Pd_en[3,0]=val_data_1_1[3]

    Pd_en[1,2]=val_data_1_1[5]
    Pd_en[2,1]=val_data_1_1[5]

    Pd_en[1,3]=val_data_1_1[6]
    Pd_en[3,1]=val_data_1_1[6]

    Pd_en[2,3]=val_data_1_1[8]
    Pd_en[3,2]=val_data_1_1[8]

    en_dis_1.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_2_1[0]
    Pd_en[1,1]=val_data_2_1[4]
    Pd_en[2,2]=val_data_2_1[7]
    Pd_en[3,3]=val_data_2_1[9]

    Pd_en[0,1]=val_data_2_1[1]
    Pd_en[1,0]=val_data_2_1[1]

    Pd_en[0,2]=val_data_2_1[2]
    Pd_en[2,0]=val_data_2_1[2]

    Pd_en[0,3]=val_data_2_1[3]
    Pd_en[3,0]=val_data_2_1[3]

    Pd_en[1,2]=val_data_2_1[5]
    Pd_en[2,1]=val_data_2_1[5]

    Pd_en[1,3]=val_data_2_1[6]
    Pd_en[3,1]=val_data_2_1[6]

    Pd_en[2,3]=val_data_2_1[8]
    Pd_en[3,2]=val_data_2_1[8]

    en_dis_2.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_3_1[0]
    Pd_en[1,1]=val_data_3_1[4]
    Pd_en[2,2]=val_data_3_1[7]
    Pd_en[3,3]=val_data_3_1[9]

    Pd_en[0,1]=val_data_3_1[1]
    Pd_en[1,0]=val_data_3_1[1]

    Pd_en[0,2]=val_data_3_1[2]
    Pd_en[2,0]=val_data_3_1[2]

    Pd_en[0,3]=val_data_3_1[3]
    Pd_en[3,0]=val_data_3_1[3]

    Pd_en[1,2]=val_data_3_1[5]
    Pd_en[2,1]=val_data_3_1[5]

    Pd_en[1,3]=val_data_3_1[6]
    Pd_en[3,1]=val_data_3_1[6]

    Pd_en[2,3]=val_data_3_1[8]
    Pd_en[3,2]=val_data_3_1[8]

    en_dis_3.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_4_1[0]
    Pd_en[1,1]=val_data_4_1[4]
    Pd_en[2,2]=val_data_4_1[7]
    Pd_en[3,3]=val_data_4_1[9]

    Pd_en[0,1]=val_data_4_1[1]
    Pd_en[1,0]=val_data_4_1[1]

    Pd_en[0,2]=val_data_4_1[2]
    Pd_en[2,0]=val_data_4_1[2]

    Pd_en[0,3]=val_data_4_1[3]
    Pd_en[3,0]=val_data_4_1[3]

    Pd_en[1,2]=val_data_4_1[5]
    Pd_en[2,1]=val_data_4_1[5]

    Pd_en[1,3]=val_data_4_1[6]
    Pd_en[3,1]=val_data_4_1[6]

    Pd_en[2,3]=val_data_4_1[8]
    Pd_en[3,2]=val_data_4_1[8]

    en_dis_4.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

# %%
with open(path+'EXT_expvals_s_30_1.npy', 'rb') as f:
    ext_val=np.load(f)

# %%
Pd_ex=np.zeros((4,4),dtype=np.complex128)
Pd_ex[0,0]=ext_val[0]
Pd_ex[1,1]=ext_val[4]
Pd_ex[2,2]=ext_val[7]
Pd_ex[3,3]=ext_val[9]

Pd_ex[0,1]=ext_val[1]
Pd_ex[1,0]=ext_val[1]

Pd_ex[0,2]=ext_val[2]
Pd_ex[2,0]=ext_val[2]

Pd_ex[0,3]=ext_val[3]
Pd_ex[3,0]=ext_val[3]

Pd_ex[1,2]=ext_val[5]
Pd_ex[2,1]=ext_val[5]

Pd_ex[1,3]=ext_val[6]
Pd_ex[3,1]=ext_val[6]

Pd_ex[2,3]=ext_val[8]
Pd_ex[3,2]=ext_val[8]

# %%
with open(path+'Unenc_u_30_m.pickle', 'rb') as handle:
    uval_data_10_all = pickle.load(handle)
with open(path+'enc_val_1_u_30_ft.pickle', 'rb') as handle:
    val_data_1_1_all = pickle.load(handle)
with open(path+'enc_val_2_u_30_ft.pickle', 'rb') as handle:
    val_data_2_1_all = pickle.load(handle)
with open(path+'enc_val_3_u_30_ft.pickle', 'rb') as handle:
    val_data_3_1_all = pickle.load(handle)
with open(path+'enc_val_4_u_30_ft.pickle', 'rb') as handle:
    val_data_4_1_all = pickle.load(handle)

un_dis_30=[]
en_dis_4_30=[]
en_dis_3_30=[]
en_dis_2_30=[]
en_dis_1_30=[]
for string in ['0.1','0.2','0.5','1.0','2.0']:
    uval_data_10=uval_data_10_all[string]
    val_data_1_1=val_data_1_1_all[string]
    val_data_2_1=val_data_2_1_all[string]
    val_data_3_1=val_data_3_1_all[string]
    val_data_4_1=val_data_4_1_all[string]

    Pd_un=np.zeros((4,4),dtype=np.complex128)
    Pd_un[0,0]=uval_data_10[0]
    Pd_un[1,1]=uval_data_10[4]
    Pd_un[2,2]=uval_data_10[7]
    Pd_un[3,3]=uval_data_10[9]

    Pd_un[0,1]=uval_data_10[1]
    Pd_un[1,0]=uval_data_10[1]

    Pd_un[0,2]=uval_data_10[2]
    Pd_un[2,0]=uval_data_10[2]

    Pd_un[0,3]=uval_data_10[3]
    Pd_un[3,0]=uval_data_10[3]

    Pd_un[1,2]=uval_data_10[5]
    Pd_un[2,1]=uval_data_10[5]

    Pd_un[1,3]=uval_data_10[6]
    Pd_un[3,1]=uval_data_10[6]

    Pd_un[2,3]=uval_data_10[8]
    Pd_un[3,2]=uval_data_10[8]

    un_dis_30.append(0.5*scipy.linalg.norm(Pd_un-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_1_1[0]
    Pd_en[1,1]=val_data_1_1[4]
    Pd_en[2,2]=val_data_1_1[7]
    Pd_en[3,3]=val_data_1_1[9]

    Pd_en[0,1]=val_data_1_1[1]
    Pd_en[1,0]=val_data_1_1[1]

    Pd_en[0,2]=val_data_1_1[2]
    Pd_en[2,0]=val_data_1_1[2]

    Pd_en[0,3]=val_data_1_1[3]
    Pd_en[3,0]=val_data_1_1[3]

    Pd_en[1,2]=val_data_1_1[5]
    Pd_en[2,1]=val_data_1_1[5]

    Pd_en[1,3]=val_data_1_1[6]
    Pd_en[3,1]=val_data_1_1[6]

    Pd_en[2,3]=val_data_1_1[8]
    Pd_en[3,2]=val_data_1_1[8]

    en_dis_1_30.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_2_1[0]
    Pd_en[1,1]=val_data_2_1[4]
    Pd_en[2,2]=val_data_2_1[7]
    Pd_en[3,3]=val_data_2_1[9]

    Pd_en[0,1]=val_data_2_1[1]
    Pd_en[1,0]=val_data_2_1[1]

    Pd_en[0,2]=val_data_2_1[2]
    Pd_en[2,0]=val_data_2_1[2]

    Pd_en[0,3]=val_data_2_1[3]
    Pd_en[3,0]=val_data_2_1[3]

    Pd_en[1,2]=val_data_2_1[5]
    Pd_en[2,1]=val_data_2_1[5]

    Pd_en[1,3]=val_data_2_1[6]
    Pd_en[3,1]=val_data_2_1[6]

    Pd_en[2,3]=val_data_2_1[8]
    Pd_en[3,2]=val_data_2_1[8]

    en_dis_2_30.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_3_1[0]
    Pd_en[1,1]=val_data_3_1[4]
    Pd_en[2,2]=val_data_3_1[7]
    Pd_en[3,3]=val_data_3_1[9]

    Pd_en[0,1]=val_data_3_1[1]
    Pd_en[1,0]=val_data_3_1[1]

    Pd_en[0,2]=val_data_3_1[2]
    Pd_en[2,0]=val_data_3_1[2]

    Pd_en[0,3]=val_data_3_1[3]
    Pd_en[3,0]=val_data_3_1[3]

    Pd_en[1,2]=val_data_3_1[5]
    Pd_en[2,1]=val_data_3_1[5]

    Pd_en[1,3]=val_data_3_1[6]
    Pd_en[3,1]=val_data_3_1[6]

    Pd_en[2,3]=val_data_3_1[8]
    Pd_en[3,2]=val_data_3_1[8]

    en_dis_3_30.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

    Pd_en=np.zeros((4,4),dtype=np.complex128)
    Pd_en[0,0]=val_data_4_1[0]
    Pd_en[1,1]=val_data_4_1[4]
    Pd_en[2,2]=val_data_4_1[7]
    Pd_en[3,3]=val_data_4_1[9]

    Pd_en[0,1]=val_data_4_1[1]
    Pd_en[1,0]=val_data_4_1[1]

    Pd_en[0,2]=val_data_4_1[2]
    Pd_en[2,0]=val_data_4_1[2]

    Pd_en[0,3]=val_data_4_1[3]
    Pd_en[3,0]=val_data_4_1[3]

    Pd_en[1,2]=val_data_4_1[5]
    Pd_en[2,1]=val_data_4_1[5]

    Pd_en[1,3]=val_data_4_1[6]
    Pd_en[3,1]=val_data_4_1[6]

    Pd_en[2,3]=val_data_4_1[8]
    Pd_en[3,2]=val_data_4_1[8]

    en_dis_4_30.append(0.5*scipy.linalg.norm(Pd_en-Pd_ex))

# %%
err=[0.1,0.2,0.5,1.0,2.0]

# %%
plt.plot(err,en_dis_1_30,c='r',label='N=1', marker= 'o', markersize=3)
plt.plot(err,en_dis_2_30,c='g',label='N=2', marker= 'o', markersize=3)
plt.plot(err,en_dis_3_30,c='b',label='N=3', marker= 'o', markersize=3)
plt.plot(err,en_dis_4_30,c='m',label='N=4', marker= 'o', markersize=3)
plt.plot(err,un_dis_30,c='k',label='Unencoded', marker= 'o', markersize=3)
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.xlabel('Noise Scale')
plt.ylabel('Trace distance')
# Out:
# Text(0, 0.5, 'Trace distance')

# %%
suc_data_1_1=[]
suc_data_2_1=[]
suc_data_3_1=[]
suc_data_4_1=[]
for string in ['0.1','0.2','0.5','1.0','2.0']:
    with open(path50+'enc_suc_1_u_50_ft.pickle', 'rb') as handle:
        suc_data_1_1.append(np.mean(pickle.load(handle)[string]))
    with open(path50+'enc_suc_2_u_50_ft.pickle', 'rb') as handle:
        suc_data_2_1.append(np.mean(pickle.load(handle)[string]))
    with open(path50+'enc_suc_3_u_50_ft.pickle', 'rb') as handle:
        suc_data_3_1.append(np.mean(pickle.load(handle)[string]))
    with open(path50+'enc_suc_4_u_50_ft.pickle', 'rb') as handle:
        suc_data_4_1.append(np.mean(pickle.load(handle)[string]))

# %%
suc_data_4_1
# Out:
# [np.float64(0.9093513793762108),
#  np.float64(0.8276495408289898),
#  np.float64(0.6258129248968661),
#  np.float64(0.3984031331075993),
#  np.float64(0.1717754836572436)]

# %%
suc_data_1_1_30=[]
suc_data_2_1_30=[]
suc_data_3_1_30=[]
suc_data_4_1_30=[]
for string in ['0.1','0.2','0.5','1.0','2.0']:
    with open(path+'enc_suc_1_u_30_ft.pickle', 'rb') as handle:
        suc_data_1_1_30.append(np.mean(pickle.load(handle)[string]))
    with open(path+'enc_suc_2_u_30_ft.pickle', 'rb') as handle:
        suc_data_2_1_30.append(np.mean(pickle.load(handle)[string]))
    with open(path+'enc_suc_3_u_30_ft.pickle', 'rb') as handle:
        suc_data_3_1_30.append(np.mean(pickle.load(handle)[string]))
    with open(path+'enc_suc_4_u_30_ft.pickle', 'rb') as handle:
        suc_data_4_1_30.append(np.mean(pickle.load(handle)[string]))

# %%
suc_data_4_1_30
# Out:
# [np.float64(0.938943611317779),
#  np.float64(0.8820273853558536),
#  np.float64(0.7324965022866626),
#  np.float64(0.5400807403048361),
#  np.float64(0.29911977439831366)]

# %%
fig,axes = plt.subplots(2,3,sharex = False, sharey = False, figsize = ((3*3.375),1.4*(0.5*3.375)*2),squeeze = False)
plt.subplots_adjust(wspace=0.26, hspace=0.18)


xlabels = [
        "Unen",
        "N=1",
        "N=2",
        "N=3",
        "N=4"
        ]

axes[0,0].boxplot(errors_30, positions=positions, widths=0.6, patch_artist=True,
        boxprops=dict(facecolor=f'C{0}', color=f'C{0}'),
        medianprops=dict(color='black'))

axes[0,0].set_xticklabels([], rotation=0, fontsize=12)
axes[0,0].set_ylabel('Error of density matrix', fontsize=12)
axes[0,0].set_yscale('log')
axes[0,0].text(-0.13,1.02,r"$\mathrm{(a)}$",transform=axes[0,0].transAxes)

axes[1,0].boxplot(errors_50, positions=positions, widths=0.6, patch_artist=True,
        boxprops=dict(facecolor=f'C{0}', color=f'C{0}'),
        medianprops=dict(color='black'))

axes[1,0].set_xticklabels(xlabels, rotation=0, fontsize=12)
axes[1,0].set_ylabel('Error of density matrix', fontsize=12)
axes[1,0].set_yscale('log')
axes[1,0].text(-0.13,1.02,r"$\mathrm{(d)}$",transform=axes[1,0].transAxes)


axes[0,1].plot(err,en_dis_1_30,linestyle='-',c='g',label='N=1', marker= 'o', markersize=3)
axes[0,1].plot(err,en_dis_2_30,linestyle='--',c='m',label='N=2', marker= 'o', markersize=3)
axes[0,1].plot(err,en_dis_3_30,linestyle='-.',c='b',label='N=3', marker= 'o', markersize=3)
axes[0,1].plot(err,en_dis_4_30,linestyle=':',c='r',label='N=4', marker= 'o', markersize=3)
axes[0,1].plot(err,un_dis_30,c='k',label='Unencoded', marker= 'o', markersize=3)
axes[0,1].set_xscale('log')
axes[0,1].set_yscale('log')
axes[0,1].legend(frameon=False,handlelength=1.2,labelspacing =0.1)
#axes[1,1].set_xlabel('Noise Scale')
axes[0,1].set_ylabel(r"$\mathcal{D}(\rho_{\mu\nu,\mathrm{Exact}},\rho_{\mu\nu,\mathrm{Noisy}})$")
axes[0,1].text(-0.13,1.02,r"$\mathrm{(b)}$",transform=axes[0,1].transAxes)


axes[1,1].plot(err,en_dis_1,linestyle='-',c='g',label='N=1', marker= 'o', markersize=3)
axes[1,1].plot(err,en_dis_2,linestyle='--',c='m',label='N=2', marker= 'o', markersize=3)
axes[1,1].plot(err,en_dis_3,linestyle='-.',c='b',label='N=3', marker= 'o', markersize=3)
axes[1,1].plot(err,en_dis_4,linestyle=':',c='r',label='N=4', marker= 'o', markersize=3)
axes[1,1].plot(err,un_dis,c='k',label='Unencoded', marker= 'o', markersize=3)
axes[1,1].set_xscale('log')
axes[1,1].set_yscale('log')
axes[1,1].legend(frameon=False,handlelength=1.2,labelspacing =0.1)
axes[1,1].set_xlabel('Noise Scale (s)', fontsize=12)
axes[1,1].set_ylabel(r"$\mathcal{D}(\rho_{\mu\nu,\mathrm{Exact}},\rho_{\mu\nu,\mathrm{Noisy}})$")
axes[1,1].text(-0.13,1.02,r"$\mathrm{(e)}$",transform=axes[1,1].transAxes)

axes[0,2].plot(err,suc_data_1_1_30,linestyle='-',c='g',label='N=1', marker= 'o', markersize=3)
axes[0,2].plot(err,suc_data_2_1_30,linestyle='--',c='m',label='N=2', marker= 'o', markersize=3)
axes[0,2].plot(err,suc_data_3_1_30,linestyle='-.',c='b',label='N=3', marker= 'o', markersize=3)
axes[0,2].plot(err,suc_data_4_1_30,linestyle=':',c='r',label='N=4', marker= 'o', markersize=3)
axes[0,2].legend(frameon=False,handlelength=1.2,labelspacing =0.1)
axes[0,2].set_xscale('log')
#axes[0,2].set_xlabel('Noise Scale')
axes[0,2].set_ylabel(r"$\mathrm{Success}$ $\mathrm{Rate}$", fontsize=12)
axes[0,2].text(-0.13,1.02,r"$\mathrm{(c)}$",transform=axes[0,2].transAxes)

axes[1,2].plot(err,suc_data_1_1,linestyle='-',c='g',label='N=1', marker= 'o', markersize=3)
axes[1,2].plot(err,suc_data_2_1,linestyle='--',c='m',label='N=2', marker= 'o', markersize=3)
axes[1,2].plot(err,suc_data_3_1,linestyle='-.',c='b',label='N=3', marker= 'o', markersize=3)
axes[1,2].plot(err,suc_data_4_1,linestyle=':',c='r',label='N=4', marker= 'o', markersize=3)
axes[1,2].legend(frameon=False,handlelength=1.2,labelspacing =0.1)
axes[1,2].set_xscale('log')
axes[1,2].set_xlabel('Noise Scale (s)', fontsize=12)
axes[1,2].set_ylabel(r"$\mathrm{Success}$ $\mathrm{Rate}$", fontsize=14)
axes[1,2].text(-0.13,1.02,r"$\mathrm{(f)}$",transform=axes[1,2].transAxes)

plt.savefig("fig_2.png",dpi = 500,bbox_inches='tight',facecolor='white',transparent=False)
